# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzakhan0153/1/blob/main/Hubway_ETL_Muhammad_Hamza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setting up Spark and MongoDB

# %%
#Pre-Reqs to read and write from mongoDB
#Run it in Google Colab

# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.1/spark-3.5.1-bin-hadoop3.tgz -O spark.tgz
# !tar -xzf spark.tgz
# !pip install -q pyspark==3.5.1

import os
from pyspark.sql import SparkSession

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.1-bin-hadoop3"
os.environ["PATH"] += os.pathsep + os.path.join(os.environ["SPARK_HOME"], "bin")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 13.5 MB/s eta 0:00:00
#   Building wheel for pyspark (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dataproc-spark-connect 1.1.0 requires pyspark[connect]~=4.0.0, but you have pyspark 3.5.1 which is incompatible.

# %% [markdown]
# ### Initialize Spark Context

# %%
## CUSTOMIZE YOUR CREDENTIALS AS PER YOUR SETTING

#import findspark
#findspark.init()

#Replace MongoDB URI

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("HubwayBikeETL") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.3.0") \
    .config("spark.mongodb.read.connection.uri",
            "mongodb+srv://hamza:hamza@hamzacluster.togyiah.mongodb.net/") \
    .config("spark.mongodb.write.connection.uri",
            "mongodb+srv://hamza:hamza@hamzacluster.togyiah.mongodb.net/") \
    .getOrCreate()

# %% [markdown]
# ## YOUR ETL PIPELINE TASK
#
# ### Step 1: Data Preparation
#
# - Load the provided Trips and Stations Data into Spark DataFrame.

# %% [markdown]
# ## DATASET : BIKE SHARING DATA
#
# Trips: https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/master/data/bike-data/201508_trip_data.csv
#
# Stations: https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/master/data/bike-data/201508_station_data.csv
#
# Zip_Code_Map: https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv

# %% [markdown]
# ## Reading Data from CSV

# %%
from pyspark import SparkFiles

#Reading Trips Data into Dataframe

url = "https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/master/data/bike-data/201508_trip_data.csv"
spark.sparkContext.addFile(url)

file_path = SparkFiles.get("201508_trip_data.csv")

trips_df = spark.read.csv(file_path, header=True, inferSchema=True)
trips_df.show(5)
# Out:
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# |Trip ID|Duration|     Start Date|       Start Station|Start Terminal|       End Date|         End Station|End Terminal|Bike #|Subscriber Type|Zip Code|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# | 913460|     765|8/31/2015 23:26|Harry Bridges Pla...|            50|8/31/2015 23:39|San Francisco Cal...|          70|   288|     Subscriber|    2139|
# | 913459|    1036|8/31/2015 23:11|San Antonio Shopp...|            31|8/31/2015 23:28|Mountain View Cit...|          27|    35|     Subscriber|   95032|
# | 913455|     307|8/31/2015 23:13|      Post at Kearny|            47|8/31/2015 23:18|   2nd at South Park|          64|   468|     Subscriber|   94107|
# | 913454|     409|8/31/2015 23:10|  San Jose City Hall|            10|8/31/2015 23:17| San Salvador at 1st|           8|    68|     Subscriber|   95113|
# | 913453|     789|8/31/2015 23:09|Embarcadero at Fo...|            51|8/31/2015 23:22|Embarcadero at Sa...|          60|   487|       Customer|    9069|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# only showing top 5 rows

# %%
trips_df.printSchema()
# Out:
# root
#  |-- Trip ID: integer (nullable = true)
#  |-- Duration: integer (nullable = true)
#  |-- Start Date: string (nullable = true)
#  |-- Start Station: string (nullable = true)
#  |-- Start Terminal: integer (nullable = true)
#  |-- End Date: string (nullable = true)
#  |-- End Station: string (nullable = true)
#  |-- End Terminal: integer (nullable = true)
#  |-- Bike #: integer (nullable = true)
#  |-- Subscriber Type: string (nullable = true)
#  |-- Zip Code: string (nullable = true)

# %%
## CORRECTING COLUMN NAME FORMAT SINCE IT WILL BE HARD TO HAND SPACED COLUMN NAMES IN SPARK

import pyspark.sql.functions as F

def correct_headers(df):
  return df.select([F.col(col).alias(col.replace(' ', '_')) for col in df.columns])

## USE THIS FUNCTION TO CORRECT HEADERS AND PROCEED WITH YOUR ETL PIPELINE

# %%
trips_df.printSchema()
# Out:
# root
#  |-- Trip ID: integer (nullable = true)
#  |-- Duration: integer (nullable = true)
#  |-- Start Date: string (nullable = true)
#  |-- Start Station: string (nullable = true)
#  |-- Start Terminal: integer (nullable = true)
#  |-- End Date: string (nullable = true)
#  |-- End Station: string (nullable = true)
#  |-- End Terminal: integer (nullable = true)
#  |-- Bike #: integer (nullable = true)
#  |-- Subscriber Type: string (nullable = true)
#  |-- Zip Code: string (nullable = true)

# %%
trips_df = correct_headers(trips_df)
trips_df.show(5)
# Out:
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# |Trip_ID|Duration|     Start_Date|       Start_Station|Start_Terminal|       End_Date|         End_Station|End_Terminal|Bike_#|Subscriber_Type|Zip_Code|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# | 913460|     765|8/31/2015 23:26|Harry Bridges Pla...|            50|8/31/2015 23:39|San Francisco Cal...|          70|   288|     Subscriber|    2139|
# | 913459|    1036|8/31/2015 23:11|San Antonio Shopp...|            31|8/31/2015 23:28|Mountain View Cit...|          27|    35|     Subscriber|   95032|
# | 913455|     307|8/31/2015 23:13|      Post at Kearny|            47|8/31/2015 23:18|   2nd at South Park|          64|   468|     Subscriber|   94107|
# | 913454|     409|8/31/2015 23:10|  San Jose City Hall|            10|8/31/2015 23:17| San Salvador at 1st|           8|    68|     Subscriber|   95113|
# | 913453|     789|8/31/2015 23:09|Embarcadero at Fo...|            51|8/31/2015 23:22|Embarcadero at Sa...|          60|   487|       Customer|    9069|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# only showing top 5 rows

# %%
#Reading Station Data into Dataframe

url = "https://raw.githubusercontent.com/databricks/Spark-The-Definitive-Guide/master/data/bike-data/201508_station_data.csv"
spark.sparkContext.addFile(url)

file_path = SparkFiles.get("201508_station_data.csv")


stations_df= spark.read.csv(file_path, header=True, inferSchema=True)
stations_df = correct_headers(stations_df)
stations_df.printSchema()
stations_df.show(5)

## USE THE FUNCTION CORRECT HEADERS TO CORRECT STATION HEADERS AND PROCEED WITH YOUR ETL PIPELINE
# Out:
# root
#  |-- station_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- lat: double (nullable = true)
#  |-- long: double (nullable = true)
#  |-- dockcount: integer (nullable = true)
#  |-- landmark: string (nullable = true)
#  |-- installation: string (nullable = true)
#
# +----------+--------------------+---------+-----------+---------+--------+------------+
# |station_id|                name|      lat|       long|dockcount|landmark|installation|
# +----------+--------------------+---------+-----------+---------+--------+------------+
# |         2|San Jose Diridon ...|37.329732|-121.901782|       27|San Jose|    8/6/2013|
# |         3|San Jose Civic Ce...|37.330698|-121.888979|       15|San Jose|    8/5/2013|
# |         4|Santa Clara at Al...|37.333988|-121.894902|       11|San Jose|    8/6/2013|
# |         5|    Adobe on Almaden|37.331415|  -121.8932|       19|San Jose|    8/5/2013|
# |         6|    San Pedro Square|37.336721|-121.894074|       15|San Jose|    8/7/2013|
# +----------+--------------------+---------+-----------+---------+--------+------------+
# only showing top 5 rows

# %%
#Reading ZipCode Data into Dataframe

url = "https://raw.githubusercontent.com/scpike/us-state-county-zip/master/geo-data.csv"
spark.sparkContext.addFile(url)

file_path = SparkFiles.get("geo-data.csv")


Zip_Code_Map= spark.read.csv(file_path, header=True, inferSchema=True)
Zip_Code_Map = correct_headers(Zip_Code_Map)
Zip_Code_Map.printSchema()
Zip_Code_Map.show(5)

## USE THE FUNCTION CORRECT HEADERS TO CORRECT STATION HEADERS AND PROCEED WITH YOUR ETL PIPELINE
# Out:
# root
#  |-- state_fips: integer (nullable = true)
#  |-- state: string (nullable = true)
#  |-- state_abbr: string (nullable = true)
#  |-- zipcode: string (nullable = true)
#  |-- county: string (nullable = true)
#  |-- city: string (nullable = true)
#
# +----------+-------+----------+-------+----------+----------+
# |state_fips|  state|state_abbr|zipcode|    county|      city|
# +----------+-------+----------+-------+----------+----------+
# |         1|Alabama|        AL|  35004| St. Clair|     Acmar|
# |         1|Alabama|        AL|  35005| Jefferson|Adamsville|
# |         1|Alabama|        AL|  35006| Jefferson|     Adger|
# |         1|Alabama|        AL|  35007|    Shelby|  Keystone|
# |         1|Alabama|        AL|  35010|Tallapoosa|  New site|
# +----------+-------+----------+-------+----------+----------+
# only showing top 5 rows

# %% [markdown]
# ### Step 2: Data Transformation
#
# - Join the Trips DataFrame with the Stations DataFrame to add Starting Landmark and Ending Landmark columns. (You will require same station to be joined to trips table twice with different joining conditions)
# - Use the Zip Code Mapping dataset to add a “State” column to the Trips DataFrame, based on the available Zip Code field.
# - Extract the Month_Year from the Start Date.
# - Select Relevant Columns Required leave the rest

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import to_timestamp, date_format


trips_df = (
trips_df.alias('t').join(stations_df.alias('s'),
on=col("t.Start_Terminal") == col("s.station_id"),
how="left")
.select(col("t.*"),col("s.landmark").alias('Starting_Landmark'))
)

trips_df.show(5)

trips_df = (
trips_df.alias('t').join(stations_df.alias('s'),
on=col("t.End_Terminal") == col("s.station_id"),
how="left")
.select(col("t.*"),col("s.landmark").alias('Ending_Landmark'))
)

trips_df.show(5)

trips_df = (
    trips_df.alias('t').join(Zip_Code_Map.alias('z'),
    on=col("t.Zip_Code") == col("z.zipcode"),how="left"
    )
    .select(col("t.*"),col("z.state").alias("Customer_State"))
)
trips_df.show(5)

trips_df = trips_df.withColumn(
    "Month_Year",
    date_format(
        to_timestamp("Start_Date", "M/d/yyyy H:mm"),
        "yyyy-MM"
    )
)
trips_df.show(5)

trips_df = trips_df.select(col("Trip_ID"),col("Duration"),col("Subscriber_Type"),col("Customer_State"),col("Starting_Landmark"),col("Ending_Landmark"),col("Month_Year"))
trips_df.show(5)

trips_df = trips_df.fillna({'Customer_State':'Unknown'})
trips_df.show(5)
# Out:
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+
# |Trip_ID|Duration|     Start_Date|       Start_Station|Start_Terminal|       End_Date|         End_Station|End_Terminal|Bike_#|Subscriber_Type|Zip_Code|Starting_Landmark|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+
# | 913460|     765|8/31/2015 23:26|Harry Bridges Pla...|            50|8/31/2015 23:39|San Francisco Cal...|          70|   288|     Subscriber|    2139|    San Francisco|
# | 913459|    1036|8/31/2015 23:11|San Antonio Shopp...|            31|8/31/2015 23:28|Mountain View Cit...|          27|    35|     Subscriber|   95032|    Mountain View|
# | 913455|     307|8/31/2015 23:13|      Post at Kearny|            47|8/31/2015 23:18|   2nd at South Park|          64|   468|     Subscriber|   94107|    San Francisco|
# | 913454|     409|8/31/2015 23:10|  San Jose City Hall|            10|8/31/2015 23:17| San Salvador at 1st|           8|    68|     Subscriber|   95113|         San Jose|
# | 913453|     789|8/31/2015 23:09|Embarcadero at Fo...|            51|8/31/2015 23:22|Embarcadero at Sa...|          60|   487|       Customer|    9069|    San Francisco|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+
# only showing top 5 rows
#
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+
# |Trip_ID|Duration|     Start_Date|       Start_Station|Start_Terminal|       End_Date|         End_Station|End_Terminal|Bike_#|Subscriber_Type|Zip_Code|Starting_Landmark|Ending_Landmark|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+
# | 913460|     765|8/31/2015 23:26|Harry Bridges Pla...|            50|8/31/2015 23:39|San Francisco Cal...|          70|   288|     Subscriber|    2139|    San Francisco|  San Francisco|
# | 913459|    1036|8/31/2015 23:11|San Antonio Shopp...|            31|8/31/2015 23:28|Mountain View Cit...|          27|    35|     Subscriber|   95032|    Mountain View|  Mountain View|
# | 913455|     307|8/31/2015 23:13|      Post at Kearny|            47|8/31/2015 23:18|   2nd at South Park|          64|   468|     Subscriber|   94107|    San Francisco|  San Francisco|
# | 913454|     409|8/31/2015 23:10|  San Jose City Hall|            10|8/31/2015 23:17| San Salvador at 1st|           8|    68|     Subscriber|   95113|         San Jose|       San Jose|
# | 913453|     789|8/31/2015 23:09|Embarcadero at Fo...|            51|8/31/2015 23:22|Embarcadero at Sa...|          60|   487|       Customer|    9069|    San Francisco|  San Francisco|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+
# only showing top 5 rows
#
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+--------------+
# |Trip_ID|Duration|     Start_Date|       Start_Station|Start_Terminal|       End_Date|         End_Station|End_Terminal|Bike_#|Subscriber_Type|Zip_Code|Starting_Landmark|Ending_Landmark|Customer_State|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+--------------+
# | 913460|     765|8/31/2015 23:26|Harry Bridges Pla...|            50|8/31/2015 23:39|San Francisco Cal...|          70|   288|     Subscriber|    2139|    San Francisco|  San Francisco|          NULL|
# | 913459|    1036|8/31/2015 23:11|San Antonio Shopp...|            31|8/31/2015 23:28|Mountain View Cit...|          27|    35|     Subscriber|   95032|    Mountain View|  Mountain View|    California|
# | 913455|     307|8/31/2015 23:13|      Post at Kearny|            47|8/31/2015 23:18|   2nd at South Park|          64|   468|     Subscriber|   94107|    San Francisco|  San Francisco|    California|
# | 913454|     409|8/31/2015 23:10|  San Jose City Hall|            10|8/31/2015 23:17| San Salvador at 1st|           8|    68|     Subscriber|   95113|         San Jose|       San Jose|    California|
# | 913453|     789|8/31/2015 23:09|Embarcadero at Fo...|            51|8/31/2015 23:22|Embarcadero at Sa...|          60|   487|       Customer|    9069|    San Francisco|  San Francisco|          NULL|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+--------------+
# only showing top 5 rows
#
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+--------------+----------+
# |Trip_ID|Duration|     Start_Date|       Start_Station|Start_Terminal|       End_Date|         End_Station|End_Terminal|Bike_#|Subscriber_Type|Zip_Code|Starting_Landmark|Ending_Landmark|Customer_State|Month_Year|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+--------------+----------+
# | 913460|     765|8/31/2015 23:26|Harry Bridges Pla...|            50|8/31/2015 23:39|San Francisco Cal...|          70|   288|     Subscriber|    2139|    San Francisco|  San Francisco|          NULL|   2015-08|
# | 913459|    1036|8/31/2015 23:11|San Antonio Shopp...|            31|8/31/2015 23:28|Mountain View Cit...|          27|    35|     Subscriber|   95032|    Mountain View|  Mountain View|    California|   2015-08|
# | 913455|     307|8/31/2015 23:13|      Post at Kearny|            47|8/31/2015 23:18|   2nd at South Park|          64|   468|     Subscriber|   94107|    San Francisco|  San Francisco|    California|   2015-08|
# | 913454|     409|8/31/2015 23:10|  San Jose City Hall|            10|8/31/2015 23:17| San Salvador at 1st|           8|    68|     Subscriber|   95113|         San Jose|       San Jose|    California|   2015-08|
# | 913453|     789|8/31/2015 23:09|Embarcadero at Fo...|            51|8/31/2015 23:22|Embarcadero at Sa...|          60|   487|       Customer|    9069|    San Francisco|  San Francisco|          NULL|   2015-08|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+-----------------+---------------+--------------+----------+
# only showing top 5 rows
#
# +-------+--------+---------------+--------------+-----------------+---------------+----------+
# |Trip_ID|Duration|Subscriber_Type|Customer_State|Starting_Landmark|Ending_Landmark|Month_Year|
# +-------+--------+---------------+--------------+-----------------+---------------+----------+
# | 913460|     765|     Subscriber|          NULL|    San Francisco|  San Francisco|   2015-08|
# | 913459|    1036|     Subscriber|    California|    Mountain View|  Mountain View|   2015-08|
# | 913455|     307|     Subscriber|    California|    San Francisco|  San Francisco|   2015-08|
# | 913454|     409|     Subscriber|    California|         San Jose|       San Jose|   2015-08|
# | 913453|     789|       Customer|          NULL|    San Francisco|  San Francisco|   2015-08|
# +-------+--------+---------------+--------------+-----------------+---------------+----------+
# only showing top 5 rows
#
# +-------+--------+---------------+--------------+-----------------+---------------+----------+
# |Trip_ID|Duration|Subscriber_Type|Customer_State|Starting_Landmark|Ending_Landmark|Month_Year|
# +-------+--------+---------------+--------------+-----------------+---------------+----------+
# | 913460|     765|     Subscriber|       Unknown|    San Francisco|  San Francisco|   2015-08|
# | 913459|    1036|     Subscriber|    California|    Mountain View|  Mountain View|   2015-08|
# | 913455|     307|     Subscriber|    California|    San Francisco|  San Francisco|   2015-08|
# | 913454|     409|     Subscriber|    California|         San Jose|       San Jose|   2015-08|
# | 913453|     789|       Customer|       Unknown|    San Francisco|  San Francisco|   2015-08|
# +-------+--------+---------------+--------------+-----------------+---------------+----------+
# only showing top 5 rows

# %% [markdown]
# ### Step 3: Data Aggregation
#
# - Group the DataFrame by Starting Landmark, Ending Landmark, State, Subscriber Type, and Month_Year.
# - Calculate the following measures:
#   - Number_of_Trips (count distinct Trip_ID)
#   - Duration_Total_Minutes (sum of Duration) / 60

# %%
from pyspark.sql.functions import count,countDistinct,sum,round
trips_df.printSchema()

trips_df = trips_df.groupBy(
    "Starting_Landmark",
    "Ending_Landmark",
    "Customer_State",
    "Subscriber_Type",
    "Month_Year"
).agg(
    countDistinct("Trip_ID").alias("Number_Of_Trip"),
    round((sum(col("Duration"))/60),2).alias("Duration_Total_minutes")
)

trips_df.show(50)
# Out:
# root
#  |-- Trip_ID: integer (nullable = true)
#  |-- Duration: integer (nullable = true)
#  |-- Subscriber_Type: string (nullable = true)
#  |-- Customer_State: string (nullable = false)
#  |-- Starting_Landmark: string (nullable = true)
#  |-- Ending_Landmark: string (nullable = true)
#  |-- Month_Year: string (nullable = true)
#
# +-----------------+---------------+--------------+---------------+----------+--------------+----------------------+
# |Starting_Landmark|Ending_Landmark|Customer_State|Subscriber_Type|Month_Year|Number_Of_Trip|Duration_Total_minutes|
# +-----------------+---------------+--------------+---------------+----------+--------------+----------------------+
# |     Redwood City|   Redwood City|    California|     Subscriber|   2015-03|           135|                1290.5|
# |    San Francisco|  San Francisco|         Texas|       Customer|   2015-02|            92|               5472.78|
# |         San Jose|       San Jose|       Georgia|       Customer|   2015-03|             4|                164.97|
# |    San Francisco|  San Francisco|       Georgia|       Customer|   2015-01|            19|                723.75|
# |         San Jose|       San Jose|         Texas|       Customer|   2014-09|             2|                248.72|
# |        Palo Alto|   Redwood City|    Washington|       Customer|   2014-12|             2|                 63.95|
# |    San Francisco|  San Francisco|      Colorado|       Customer|   2015-05|           107|               2876.22|
# |    San Francisco|  San Francisco|        Nevada|       Customer|   2015-04|            16|               1236.18|
# |    San Francisco|  San Francisco|       Indiana|       Customer|   2015-07|             5|                 233.8|
# |    San Francisco|  San Francisco|    California|       Customer|   2014-10|          1560|               65992.4|
# |         San Jose|       San Jose|      Colorado|       Customer|   2015-01|             1|                 47.05|
# |    San Francisco|  San Francisco|      Missouri|       Customer|   2014-10|            11|                406.62|
# |    San Francisco|  San Francisco|      Colorado|     Subscriber|   2014-11|             6|                 52.77|
# |        Palo Alto|  Mountain View|    California|       Customer|   2015-01|             4|                101.83|
# |    Mountain View|  Mountain View|        Alaska|       Customer|   2014-09|             1|                175.53|
# |         San Jose|       San Jose|    California|       Customer|   2015-06|           178|              14206.28|
# |    Mountain View|  Mountain View|        Oregon|       Customer|   2015-08|             2|                 161.4|
# |    San Francisco|  San Francisco|    New jersey|       Customer|   2015-08|             4|                 37.88|
# |        Palo Alto|   Redwood City|    California|     Subscriber|   2015-07|             4|                106.17|
# |        Palo Alto|      Palo Alto|      Illinois|       Customer|   2015-07|             4|                217.63|
# |         San Jose|       San Jose|       Florida|       Customer|   2014-10|            11|                233.97|
# |    San Francisco|  San Francisco|      New york|       Customer|   2014-11|            72|               2673.92|
# |    San Francisco|  San Francisco|       Alabama|       Customer|   2014-12|             6|                 131.3|
# |         San Jose|       San Jose|         Texas|       Customer|   2015-03|             3|                552.65|
# |    San Francisco|  San Francisco|     Louisiana|       Customer|   2015-05|             2|                628.53|
# |    Mountain View|  Mountain View|       Unknown|     Subscriber|   2014-10|            18|                215.43|
# |    San Francisco|  San Francisco|      Kentucky|       Customer|   2014-11|             2|                 24.83|
# |    San Francisco|  San Francisco|     Tennessee|       Customer|   2015-02|             3|                299.57|
# |    Mountain View|      Palo Alto|      New york|       Customer|   2015-06|             1|                  28.5|
# |    Mountain View|  Mountain View|        Oregon|       Customer|   2015-06|             3|                  77.5|
# |    San Francisco|  San Francisco|    California|     Subscriber|   2015-01|         22279|             211191.47|
# |    San Francisco|  San Francisco|       Arizona|     Subscriber|   2015-02|             8|                303.17|
# |        Palo Alto|      Palo Alto|      New york|       Customer|   2015-01|             4|                 61.28|
# |    San Francisco|  San Francisco|         Texas|     Subscriber|   2014-09|             2|                 34.78|
# |    San Francisco|  San Francisco|      New york|       Customer|   2015-06|           177|               6922.43|
# |    San Francisco|  San Francisco|        Oregon|       Customer|   2015-08|            32|               1173.68|
# |        Palo Alto|  Mountain View|    California|       Customer|   2015-03|             1|                 21.42|
# |    Mountain View|  Mountain View|          Ohio|       Customer|   2015-03|             2|                293.62|
# |    San Francisco|  San Francisco|      Virginia|       Customer|   2015-02|             6|                227.98|
# |    San Francisco|  San Francisco|       Unknown|     Subscriber|   2015-05|           577|               4656.77|
# |    Mountain View|      Palo Alto|    California|       Customer|   2015-08|             7|                231.25|
# |    San Francisco|  San Francisco|        Oregon|       Customer|   2015-04|            27|                 885.7|
# |        Palo Alto|      Palo Alto|  Pennsylvania|       Customer|   2015-08|             2|                 848.5|
# |        Palo Alto|      Palo Alto|    California|       Customer|   2015-01|            38|               1817.68|
# |        Palo Alto|  Mountain View|    California|       Customer|   2014-09|             4|                147.23|
# |     Redwood City|   Redwood City|    California|     Subscriber|   2015-06|           225|               3047.05|
# |         San Jose|       San Jose|      Illinois|       Customer|   2015-06|            10|                697.82|
# |    San Francisco|  San Francisco|        Alaska|       Customer|   2015-02|             5|                 186.6|
# |    San Francisco|  San Francisco|       Montana|       Customer|   2015-04|             9|                199.68|
# |    San Francisco|  San Francisco|      Kentucky|       Customer|   2014-12|             5|                 303.6|
# +-----------------+---------------+--------------+---------------+----------+--------------+----------------------+
# only showing top 50 rows

# %% [markdown]
# ### Step 4: Save the Data in MongoDB for Analytics Later

# %%
trips_df.write \
    .format("mongodb") \
    .mode("overwrite") \
    .option("database", "spark_assignment") \
    .option("collection", "trips_summary") \
    .save()

# %% [markdown]
# `#### Outcome Dataframe
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Upload your Spark Transformation Notebook / Script + Your mongodb Collection screenshot

# %% [markdown]
# ![image.png](data:image/png;base64,...)
